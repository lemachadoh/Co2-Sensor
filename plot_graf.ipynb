# %%
#importando as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import datetime as dt
from datetime import datetime

SENSOR = pd.read_csv(r"C:\Users\lwmachado\Desktop\Sensores_py\CASA_LEANDRA_24.csv") #endereco do arquivo

#b'Sensor,CO2(ppm),Temperatura (C),umidade (%),Data\r\n',16/3/2022 09:16:35


#aplicando funcoes que deixam o formato do texto mais funcional
SENSOR["b'Sensor"] = SENSOR["b'Sensor"].apply(lambda x: x.replace("'","").replace("b","").replace(r"\r\n","").strip())
SENSOR["TVOC"] = SENSOR["TVOC"].apply(lambda x: x.replace("'","").replace("b","").replace(r"\r\n","").strip())
SENSOR = SENSOR.rename(columns={r"Data\r\n'": "Data"})

SENSOR = SENSOR.rename(columns={"b'Sensor": "Sensor"})
SENSOR = SENSOR.rename(columns={"TVOC": "TVOC(ppb)"})

#separando cada sensor em um data frame diferente para manipular mais tarde
SCD30_df= SENSOR['Sensor']=='SCD30';  SCD30 = SENSOR[SCD30_df]
SGP30_df= SENSOR['Sensor']=='SGP30';  SGP30 = SENSOR[SGP30_df]
CCS811_df= SENSOR['Sensor']=='CCS811';  CCS811 = SENSOR[CCS811_df]
PASCO2_df= SENSOR['Sensor']=='PASCO2';  PASCO2 = SENSOR[PASCO2_df]
SCD41_df= SENSOR['Sensor']=='SCD41';  SCD41 = SENSOR[SCD41_df]

#fazendo conversoes de str - float e str - datetime
SCD30['umidade (%)'] = pd.to_numeric(SCD30['umidade (%)'])
SCD30['Temperatura (C)'] = pd.to_numeric(SCD30['Temperatura (C)'])
SCD30['Data'] = pd.to_datetime(SCD30['Data'])

SCD41['umidade (%)'] = pd.to_numeric(SCD41['umidade (%)'])
SCD41['Temperatura (C)'] = pd.to_numeric(SCD41['Temperatura (C)'])
SCD41['Data'] = pd.to_datetime(SCD41['Data'])

PASCO2['Data'] = pd.to_datetime(PASCO2['Data'])

CCS811['Data'] = pd.to_datetime(CCS811['Data'])
CCS811['TVOC(ppb)'] = pd.to_numeric(CCS811['TVOC(ppb)'])

SGP30['Data'] = pd.to_datetime(SGP30['Data'])
SGP30['TVOC(ppb)'] = pd.to_numeric(SGP30['TVOC(ppb)'])
# Out:
# C:\Users\lwmachado\AppData\Local\Temp\ipykernel_16268\3989881955.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SCD30['umidade (%)'] = pd.to_numeric(SCD30['umidade (%)'])
# C:\Users\lwmachado\AppData\Local\Temp\ipykernel_16268\3989881955.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SCD30['Temperatura (C)'] = pd.to_numeric(SCD30['Temperatura (C)'])
# C:\Users\lwmachado\AppData\Local\Temp\ipykernel_16268\3989881955.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SCD30['Data'] = pd.to_datetime(SCD30['Data'])
# C:\Users\lwmachado\AppData\Local\Temp\ipykernel_16268\3989881955.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SCD41['umidade (%)'] = pd.to_numeric(SCD41['umidade (%)'])
# C:\Users\lwmachado\AppData\Local\Temp\ipykernel_16268\3989881955.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SCD41['Temperatura (C)'] = pd.to_numeric(SCD41['Temperatura (C)'])
# C:\Users\lwmachado\AppData\Local\Temp\ipykernel_16268\3989881955.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SCD41['Data'] = pd.to_datetime(SCD41['Data'])
# C:\Users\lwmachado\AppData\Local\Temp\ipykernel_16268\3989881955.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PASCO2['Data'] = pd.to_datetime(PASCO2['Data'])
# C:\Users\lwmachado\AppData\Local\Temp\ipykernel_16268\3989881955.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CCS811['Data'] = pd.to_datetime(CCS811['Data'])
# C:\Users\lwmachado\AppData\Local\Temp\ipykernel_16268\3989881955.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CCS811['TVOC(ppb)'] = pd.to_numeric(CCS811['TVOC(ppb)'])
# C:\Users\lwmachado\AppData\Local\Temp\ipykernel_16268\3989881955.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SGP30['Data'] = pd.to_datetime(SGP30['Data'])
# C:\Users\lwmachado\AppData\Local\Temp\ipykernel_16268\3989881955.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   
0     Temperatura     Umidade      TVOC  17/3/2022 13:42:33
# 36   SCD30     410.0           24.61       66.05      TVOC  17/3/2022 13:42:38
# 37   SCD41     380.0           32.22       40.98      TVOC  17/3/2022 13:42:38
# 38  CCS811     905.0     Temperatura     Umidade     76.00  17/3/2022 13:42:38
# 39   SGP30     411.0     Temperatura     Umidade      0.00  17/3/2022 13:42:38
# 40  PASCO2     468.0     Temperatura     Umidade      TVOC  17/3/2022 13:42:40
# 41   SCD30     414.0           24.49       66.02      TVOC  17/3/2022 13:42:45
# 42   SCD41     380.0           31.96       41.37      TVOC  17/3/2022 13:42:45
# 43  CCS811     624.0     Temperatura     Umidade     34.00  17/3/2022 13:42:46
# 44   SGP30     400.0     Temperatura     Umidade      0.00  17/3/2022 13:42:46
# 45  PASCO2     467.0     Temperatura     Umidade      TVOC  17/3/2022 13:42:48
# 46   SCD30     418.0           24.38       65.89      TVOC  17/3/2022 13:42:53
# 47   SCD41     381.0           31.90       41.38      TVOC  17/3/2022 13:42:53
# 48  CCS811     813.0     Temperatura     Umidade     62.00  17/3/2022 13:42:53
# 49   SGP30     400.0     Temperatura     Umidade      0.00  17/3/2022 13:42:53

# %%
#plotando graficos comparacao
plt.figure(figsize=(15, 10))
plt.plot(SCD30['Data'],SCD30['CO2(ppm)'], label = 'SCD30')
plt.plot(SCD41['Data'],SCD41['CO2(ppm)'], label = 'SCD41')
plt.plot(SGP30['Data'],SGP30['CO2(ppm)'],label= 'SGP30')
plt.plot(PASCO2['Data'], PASCO2['CO2(ppm)'], label = 'PASCO2')
plt.plot(CCS811['Data'], CCS811['CO2(ppm)'], label = 'CCS811')
plt.xlabel("DIA E HORA")
plt.ylabel("ppm")
plt.plot()
plt.legend()

# %%
#plot dos sensores sozinhos SCD30
plt.figure(figsize=(15, 10))
plt.plot(SCD30['Data'],SCD30['CO2(ppm)'], label = 'CO2 (ppm)')
plt.plot(SCD30['Data'], SCD30['umidade (%)'], label = 'Umidade')
plt.plot(SCD30['Data'], SCD30['Temperatura (C)'], label = 'Temperatura')
plt.title("SCD30")
plt.legend()
plt.xlabel("DIA E HORA")
plt.ylabel('ainda nao sei')
plt.plot()
# Out:
# []

# %%
#plot dos sensores sozinhos SCD41
plt.figure(figsize=(15, 10))
plt.plot(SCD41['Data'],SCD41['CO2(ppm)'], label = 'CO2 (ppm)')
plt.plot(SCD41['Data'], SCD41['umidade (%)'], label = 'Umidade')
plt.plot(SCD41['Data'], SCD41['Temperatura (C)'], label = 'Temperatura')
plt.title("SCD41")
plt.legend()
plt.xlabel("DIA E HORA")
plt.ylabel('ainda nao sei')
plt.plot()
# Out:
# []

# %%
#plot dos sensores sozinhos CCS811
plt.figure(figsize=(15, 10))
plt.plot(CCS811['Data'],SCD41['CO2(ppm)'], label = 'CO2 (ppm)')
plt.plot(CCS811['Data'], CCS811['TVOC(ppb)'], label = 'TVOC(ppb)')
plt.title("CCS811")
plt.legend()
plt.xlabel("DIA E HORA")
plt.ylabel('ainda nao sei')
plt.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\lwmachado\Desktop\PANDAS_SENSOR\plot_graf.ipynb Cell 6' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/lwmachado/Desktop/PANDAS_SENSOR/plot_graf.ipynb#ch0000005?line=0'>1</a> #plot dos sensores sozinhos CCS811
#       <a href='vscode-notebook-cell:/c%3A/Users/lwmachado/Desktop/PANDAS_SENSOR/plot_graf.ipynb#ch0000005?line=1'>2</a> plt.figure(figsize=(15, 10))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lwmachado/Desktop/PANDAS_SENSOR/plot_graf.ipynb#ch0000005?line=2'>3</a> plt.plot(CCS811['Data'],SCD41['CO2(ppm)'], label = 'CO2 (ppm)')
#       <a href='vscode-notebook-cell:/c%3A/Users/lwmachado/Desktop/PANDAS_SENSOR/plot_graf.ipynb#ch0000005?line=3'>4</a> plt.plot(CCS811['Data'], CCS811['TVOC(ppb)'], label = 'TVOC(ppb)')
#       <a href='vscode-notebook-cell:/c%3A/Users/lwmachado/Desktop/PANDAS_SENSOR/plot_graf.ipynb#ch0000005?line=4'>5</a> plt.title("CCS811")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/pyplot.py?line=2754'>2755</a> @_copy_docstring_and_deprecators(Axes.plot)
#    <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/pyplot.py?line=2755'>2756</a> def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/pyplot.py?line=2756'>2757</a>     return gca().plot(
#    <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/pyplot.py?line=2757'>2758</a>         *args, scalex=scalex, scaley=scaley,
#    <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/pyplot.py?line=2758'>2759</a>         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/axes/_axes.py?line=1389'>1390</a> """
#    <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/axes/_axes.py?line=1390'>1391</a> Plot y versus x as lines and/or markers.
#    <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/axes/_axes.py?line=1391'>1392</a>
#    (...)
#    <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/axes/_axes.py?line=1628'>1629</a> (``'green'``) or hex strings (``'#008000'``).
#    <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/axes/_axes.py?line=1629'>1630</a> """
#    <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/axes/_axes.py?line=1630'>1631</a> kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/axes/_axes.py?line=1631'>1632</a> lines = [*self._get_lines(*args, data=data, **kwargs)]
#    <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/axes/_axes.py?line=1632'>1633</a> for line in lines:
#    <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/axes/_axes.py?line=1633'>1634</a>     self.add_line(line)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/axes/_base.py?line=309'>310</a>     this += args[0],
#     <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/axes/_base.py?line=310'>311</a>     args = args[1:]
# --> <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/axes/_base.py?line=311'>312</a> yield from self._plot_args(this, kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_base.py:498, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/axes/_base.py?line=494'>495</a>     self.axes.yaxis.update_units(y)
#     <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/axes/_base.py?line=496'>497</a> if x.shape[0] != y.shape[0]:
# --> <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/axes/_base.py?line=497'>498</a>     raise ValueError(f"x and y must have same first dimension, but "
#     <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/axes/_base.py?line=498'>499</a>                      f"have shapes {x.shape} and {y.shape}")
#     <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/axes/_base.py?line=499'>500</a> if x.ndim > 2 or y.ndim > 2:
#     <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/axes/_base.py?line=500'>501</a>     raise ValueError(f"x and y can be no greater than 2D, but have "
#     <a href='file:///c%3A/Users/lwmachado/AppData/Local/Programs/Python/Python310/lib/site-packages/matplotlib/axes/_base.py?line=501'>502</a>                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (8799,) and (8801,)

# %%
#plot dos sensores sozinhos SGP30
plt.figure(figsize=(15, 10))
plt.plot(SGP30['Data'],SGP30['CO2(ppm)'], label = 'CO2 (ppm)')
plt.plot(SGP30['Data'], SGP30['TVOC(ppb)'], label = 'TVOC(ppb)')
plt.title("SGP30")
plt.legend()
plt.xlabel("DIA E HORA")
plt.ylabel('ainda nao sei')
plt.plot()

# %%
#plot dos sensores sozinhos PASO2
plt.figure(figsize=(15, 10))
plt.plot(PASCO2['Data'],PASCO2['CO2(ppm)'], label = 'CO2 (ppm)')
plt.title("PASCO2")
plt.legend()
plt.xlabel("DIA E HORA")
plt.ylabel('ainda nao sei')
plt.plot()
# Out:
# []

# %%
#COMPARACAO SENSORES NDIR

plt.figure(figsize=(15,10))
#plt.plot(SCD30['Data'], SCD30['CO2(ppm)'], label = 'SCD30')
plt.plot(SCD41['Data'], SCD41['CO2(ppm)'], label = 'SCD41')
plt.plot(PASCO2['Data'], PASCO2['CO2(ppm)'], label = 'PASCO2')
plt.xlabel('DIA E HORÁRIO')
plt.ylabel('ppm')
plt.title('Comparação sensores com tecnologia Fotoacústico')
plt.legend()
plt.plot()
# Out:
# []

# %%
#COMPARACAO SENSORES NDIR

plt.figure(figsize=(15,10))
plt.plot(SCD30['Data'], SCD30['CO2(ppm)'], label = 'SCD30')
plt.plot(SCD41['Data'], SCD41['CO2(ppm)'], label = 'SCD41')
plt.plot(PASCO2['Data'], PASCO2['CO2(ppm)'], label = 'PASCO2')
plt.xlabel('DIA E HORÁRIO')
plt.ylabel('ppm')
plt.title('Comparação de tecnologia NDIR com Fotoacústico')
plt.legend()
plt.plot()
# Out:
# []

# %%
#COMPARACAO SENSORES TVOC
plt.figure(figsize=(15,10))
plt.plot(SGP30['Data'], SGP30['CO2(ppm)'], label = 'SGP30')
plt.plot(CCS811['Data'], CCS811['CO2(ppm)'], label = 'CCS811')
plt.xlabel('DIA E HORÁRIO')
plt.ylabel('ppm')
plt.title('Comparação sensores com tecnologia TVOC/eCO2')
plt.legend()
plt.plot()
# Out:
# []
